# %%
#se importan las librerias a usar
import csv
import json
import numpy as np
import pandas as pd
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#se define una funcion para leer formatos json
def leer_contenido(ruta_archivo):
    with open(ruta_archivo, 'r', encoding='utf-8') as archivo:
        contenido = json.load(archivo)
    return contenido

# %%
#se lee el contenido del formato json
datos = leer_contenido("data/transformaciones.json")

# %%
#se realizan las primeras impresiones de los datos en el dataframe
data_frame = pd.DataFrame(datos)
data_frame.head()
# Out:
#                  departamento       ciudad        orden  \
# 0                   Atlántico  No Definido     Nacional
# 1                   Antioquia  La Estrella  Territorial
# 2  Distrito Capital de Bogotá       Bogotá     Nacional
# 3  Distrito Capital de Bogotá       Bogotá  Territorial
# 4                   Antioquia       Itagui     Nacional
#
#                     sector       rama estado_contrato  \
# 0  Información Estadística  Ejecutivo    En ejecución
# 1   No aplica/No pertenece  Ejecutivo    En ejecución
# 2              agricultura  Ejecutivo    En ejecución
# 3         Servicio Público  Ejecutivo        Borrador
# 4                  Trabajo  Ejecutivo         Cerrado
#
#           tipo_de_contrato fecha_de_firma fecha_de_inicio_del_contrato  \
# 0  Prestación de servicios     20/09/2024                   22/09/2024
# 1  Prestación de servicios     17/02/2025                   17/02/2025
# 2  Prestación de servicios     19/02/2025                   01/03/2025
# ...

# %%
data_frame.shape #se imprime el numero de filas y columnas
# Out:
# (10, 30)

# %%
data_frame.info() #se muestra la informacion sobre las columnas y tipos de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 30 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   departamento                               10 non-null     object
#  1   ciudad                                     10 non-null     object
#  2   orden                                      10 non-null     object
#  3   sector                                     10 non-null     object
#  4   rama                                       10 non-null     object
#  5   estado_contrato                            10 non-null     object
#  6   tipo_de_contrato                           10 non-null     object
#  7   fecha_de_firma                             9 non-null      object
#  8   fecha_de_inicio_del_contrato               9 non-null      object
#  9   fecha_de_fin_del_contrato                  9 non-null      object
# ...

# %%
data_frame.describe() #se muestra las estadisticas descriptivas de las columnas numericas
# Out:
#        valor_del_contrato  valor_pendiente_de_pago  fecha_de_firma_dia  \
# count        1.000000e+01             1.000000e+01            9.000000
# mean         1.282119e+07             7.842231e+06           15.444444
# std          1.010611e+07             9.214225e+06            7.601170
# min          0.000000e+00             0.000000e+00            2.000000
# 25%          5.454166e+06             0.000000e+00            9.000000
# 50%          1.027182e+07             4.193333e+06           17.000000
# 75%          2.301900e+07             1.472291e+07           20.000000
# max          2.708400e+07             2.532000e+07           25.000000
#
#        fecha_de_firma_mes  fecha_de_firma_anio  \
# count            9.000000             9.000000
# mean             5.444444          2023.222222
# std              4.245913             1.563472
# min              1.000000          2020.000000
# 25%              2.000000          2023.000000
# ...

# %%
data_frame.isnull().sum() #se muestra el numero de valores faltantes por columnas
# Out:
# departamento                                 0
# ciudad                                       0
# orden                                        0
# sector                                       0
# rama                                         0
# estado_contrato                              0
# tipo_de_contrato                             0
# fecha_de_firma                               1
# fecha_de_inicio_del_contrato                 1
# fecha_de_fin_del_contrato                    1
# destino_gasto                                0
# valor_del_contrato                           0
# valor_pendiente_de_pago                      0
# tipodocproveedor                             0
# documento_proveedor                          0
# proveedor_adjudicado                         0
# descripcion_del_proceso                      0
# fecha_de_firma_dia                           1
# fecha_de_firma_mes                           1
# fecha_de_firma_anio                          1
# ...

# %%
#se procede a revisar los casos porque son muchos registros faltantes para columnas importantes
#data_frame = data_frame.drop('fecha_de_firma', axis=1)

# %%
data_frame.isnull().sum() #se verifica 0 en el numero de valores faltantes por columnas
# Out:
# departamento                                 0
# ciudad                                       0
# orden                                        0
# sector                                       0
# rama                                         0
# estado_contrato                              0
# tipo_de_contrato                             0
# fecha_de_firma                               1
# fecha_de_inicio_del_contrato                 1
# fecha_de_fin_del_contrato                    1
# destino_gasto                                0
# valor_del_contrato                           0
# valor_pendiente_de_pago                      0
# tipodocproveedor                             0
# documento_proveedor                          0
# proveedor_adjudicado                         0
# descripcion_del_proceso                      0
# fecha_de_firma_dia                           1
# fecha_de_firma_mes                           1
# fecha_de_firma_anio                          1
# ...

# %%
data_frame.duplicated().sum() #muestra el numero de filas duplicadas
# Out:
# np.int64(0)

# %%
data_frame
# Out:
#                  departamento         ciudad        orden  \
# 0                   Atlántico    No Definido     Nacional
# 1                   Antioquia    La Estrella  Territorial
# 2  Distrito Capital de Bogotá         Bogotá     Nacional
# 3  Distrito Capital de Bogotá         Bogotá  Territorial
# 4                   Antioquia         Itagui     Nacional
# 5  Distrito Capital de Bogotá         Bogotá  Territorial
# 6                        Meta  Villavicencio  Territorial
# 7                Cundinamarca          Manta  Territorial
# 8                   Santander         Suaita  Territorial
# 9                Cundinamarca       Girardot  Territorial
#
#                     sector                  rama estado_contrato  \
# 0  Información Estadística             Ejecutivo    En ejecución
# 1   No aplica/No pertenece             Ejecutivo    En ejecución
# 2              agricultura             Ejecutivo    En ejecución
# ...

# %%
#se procede a rwevisar la opcion de eliminacion de la columna rama
data_frame = data_frame.drop('rama', axis=1)

# %%
data_frame
# Out:
#                  departamento         ciudad        orden  \
# 0                   Atlántico    No Definido     Nacional
# 1                   Antioquia    La Estrella  Territorial
# 2  Distrito Capital de Bogotá         Bogotá     Nacional
# 3  Distrito Capital de Bogotá         Bogotá  Territorial
# 4                   Antioquia         Itagui     Nacional
# 5  Distrito Capital de Bogotá         Bogotá  Territorial
# 6                        Meta  Villavicencio  Territorial
# 7                Cundinamarca          Manta  Territorial
# 8                   Santander         Suaita  Territorial
# 9                Cundinamarca       Girardot  Territorial
#
#                     sector estado_contrato         tipo_de_contrato  \
# 0  Información Estadística    En ejecución  Prestación de servicios
# 1   No aplica/No pertenece    En ejecución  Prestación de servicios
# 2              agricultura    En ejecución  Prestación de servicios
# ...

# %%
print(data_frame.shape)
# Out:
# (10, 29)

# %%
data_frame
# Out:
#                  departamento         ciudad        orden  \
# 0                   Atlántico    No Definido     Nacional
# 1                   Antioquia    La Estrella  Territorial
# 2  Distrito Capital de Bogotá         Bogotá     Nacional
# 3  Distrito Capital de Bogotá         Bogotá  Territorial
# 4                   Antioquia         Itagui     Nacional
# 5  Distrito Capital de Bogotá         Bogotá  Territorial
# 6                        Meta  Villavicencio  Territorial
# 7                Cundinamarca          Manta  Territorial
# 8                   Santander         Suaita  Territorial
# 9                Cundinamarca       Girardot  Territorial
#
#                     sector estado_contrato         tipo_de_contrato  \
# 0  Información Estadística    En ejecución  Prestación de servicios
# 1   No aplica/No pertenece    En ejecución  Prestación de servicios
# 2              agricultura    En ejecución  Prestación de servicios
# ...

# %%
data_frame.shape
# Out:
# (10, 29)

# %%
data_frame.to_csv("data/archivo_limpio.csv", index=False)
print(data_frame)
# Out:
#                  departamento         ciudad        orden  \
# 0                   Atlántico    No Definido     Nacional
# 1                   Antioquia    La Estrella  Territorial
# 2  Distrito Capital de Bogotá         Bogotá     Nacional
# 3  Distrito Capital de Bogotá         Bogotá  Territorial
# 4                   Antioquia         Itagui     Nacional
# 5  Distrito Capital de Bogotá         Bogotá  Territorial
# 6                        Meta  Villavicencio  Territorial
# 7                Cundinamarca          Manta  Territorial
# 8                   Santander         Suaita  Territorial
# 9                Cundinamarca       Girardot  Territorial
#
#                     sector estado_contrato         tipo_de_contrato  \
# 0  Información Estadística    En ejecución  Prestación de servicios
# 1   No aplica/No pertenece    En ejecución  Prestación de servicios
# 2              agricultura    En ejecución  Prestación de servicios
# ...
